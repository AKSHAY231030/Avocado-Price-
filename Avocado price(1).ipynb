# %%
# library
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\Abhishek\\Downloads\\avocado.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
data.shape
# Out:
# (18249, 14)

# %%
data.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
data['type'].value_counts()
# Out:
# type
# conventional    9126
# organic         9123
# Name: count, dtype: int64

# %%
data['type']=data['type'].map({'conventional':0,'organic':1})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  int64
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
re=data['region'].value_counts()

# %%
sns.countplot(x='year',data=data,hue='type')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
data['year'].value_counts()
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
sns.boxplot(y='year',x='AveragePrice',data=data)
# Out:
# <Axes: xlabel='AveragePrice', ylabel='year'>

# %%
data['Date']=data['Date'].apply(pd.to_datetime)

# %%
data['Date']
# Out:
# 0       2015-12-27
# 1       2015-12-20
# 2       2015-12-13
# 3       2015-12-06
# 4       2015-11-29
#            ...
# 18244   2018-02-04
# 18245   2018-01-28
# 18246   2018-01-21
# 18247   2018-01-14
# 18248   2018-01-07
# Name: Date, Length: 18249, dtype: datetime64[ns]

# %%
data['month']=data['Date'].apply(lambda x:x.month)

# %%
data
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data['month'] = data['month'].map({1:'JAN', 2:'FEB', 3:'MARCH', 4:'APRIL', 5:'MAY', 6:'JUNE', 7:'JULY', 8:'AUG', 9:'SEPT', 10:'OCT', 11:'NOV', 12:'DEC'})

# %%
data['month']
# Out:
# 0        DEC
# 1        DEC
# 2        DEC
# 3        DEC
# 4        NOV
#         ...
# 18244    FEB
# 18245    JAN
# 18246    JAN
# 18247    JAN
# 18248    JAN
# Name: month, Length: 18249, dtype: object

# %%
sns.countplot(x='month',data=data)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
dumies=pd.get_dummies(data[['year','region','month']],drop_first=True)

# %%
dumies.columns
# Out:
# Index(['year', 'region_Atlanta', 'region_BaltimoreWashington', 'region_Boise',
#        'region_Boston', 'region_BuffaloRochester', 'region_California',
#        'region_Charlotte', 'region_Chicago', 'region_CincinnatiDayton',
#        'region_Columbus', 'region_DallasFtWorth', 'region_Denver',
#        'region_Detroit', 'region_GrandRapids', 'region_GreatLakes',
#        'region_HarrisburgScranton', 'region_HartfordSpringfield',
#        'region_Houston', 'region_Indianapolis', 'region_Jacksonville',
#        'region_LasVegas', 'region_LosAngeles', 'region_Louisville',
#        'region_MiamiFtLauderdale', 'region_Midsouth', 'region_Nashville',
#        'region_NewOrleansMobile', 'region_NewYork', 'region_Northeast',
#        'region_NorthernNewEngland', 'region_Orlando', 'region_Philadelphia',
#        'region_PhoenixTucson', 'region_Pittsburgh', 'region_Plains',
#        'region_Portland', 'region_RaleighGreensboro', 'region_RichmondNorfolk',
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region', 'month'],
#       dtype='object')

# %%
x=pd.concat([data[['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','type','year','region','month']],dumies],axis=1)

# %%
if'AveragePrice'in x.columns:
    print('present')
else:
    pass

# %%
y=data['AveragePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#        Total Volume        4046       4225      4770  Total Bags  Small Bags  \
# 8704     1316347.07   548774.22  292561.60   6066.33   468944.92   355573.55
# 5271       83933.43    24615.83   16234.66   2321.26    40761.68    40759.30
# 7654      267806.51    89083.09   79805.02   1830.85    97087.55    90560.26
# 2417     4295280.16  2713600.49  592279.23  97111.62   892288.82   621425.86
# 11906      13816.71     6430.36    4300.00      0.00     3086.35     2744.50
# ...             ...         ...        ...       ...         ...         ...
# 11284      12946.65     2398.15   10206.13      0.00      342.37      342.37
# 11964       1193.06       26.72     346.19      0.00      820.15      820.15
# 5390       83407.69      992.24   54950.48    769.07    26695.90    26695.90
# 860       277578.88    42766.16  140403.76   2028.31    92380.65    87952.58
# 15795       3551.43      568.01    1410.33      0.00     1573.09      959.37
#
# ...

# %%
x_train.describe()
# Out:
#        Total Volume          4046          4225          4770    Total Bags  \
# count  1.277400e+04  1.277400e+04  1.277400e+04  1.277400e+04  1.277400e+04
# mean   8.578282e+05  2.968289e+05  2.973973e+05  2.307094e+04  2.405289e+05
# std    3.449748e+06  1.256147e+06  1.215377e+06  1.097369e+05  9.767171e+05
# min    3.855500e+02  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.088555e+04  8.684775e+02  3.007135e+03  0.000000e+00  5.104812e+03
# 50%    1.098331e+05  8.952065e+03  2.942765e+04  1.932900e+02  4.065019e+04
# 75%    4.340189e+05  1.132389e+05  1.508345e+05  6.242055e+03  1.119585e+05
# max    5.228870e+07  1.778761e+07  2.047057e+07  2.546439e+06  1.580470e+07
#
#          Small Bags    Large Bags    XLarge Bags          type          year  \
# count  1.277400e+04  1.277400e+04   12774.000000  12774.000000  12774.000000
# mean   1.826416e+05  5.470759e+04    3179.740078      0.498434   2016.148974
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
s=scaler.fit(x_train[['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']])

# %%
x_train
# Out:
#        Total Volume        4046       4225      4770  Total Bags  Small Bags  \
# 8704     1316347.07   548774.22  292561.60   6066.33   468944.92   355573.55
# 5271       83933.43    24615.83   16234.66   2321.26    40761.68    40759.30
# 7654      267806.51    89083.09   79805.02   1830.85    97087.55    90560.26
# 2417     4295280.16  2713600.49  592279.23  97111.62   892288.82   621425.86
# 11906      13816.71     6430.36    4300.00      0.00     3086.35     2744.50
# ...             ...         ...        ...       ...         ...         ...
# 11284      12946.65     2398.15   10206.13      0.00      342.37      342.37
# 11964       1193.06       26.72     346.19      0.00      820.15      820.15
# 5390       83407.69      992.24   54950.48    769.07    26695.90    26695.90
# 860       277578.88    42766.16  140403.76   2028.31    92380.65    87952.58
# 15795       3551.43      568.01    1410.33      0.00     1573.09      959.37
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
data['year_LabelEncoded'] = label_encoder.fit_transform(data['year'])

# %%
data['year'] = data['year'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ...
